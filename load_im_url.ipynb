# %% [markdown]
# <a href="https://colab.research.google.com/github/imazerty/All-In-One-Underwater-Image-Enhancement-using-Domain-Adversarial-Learning/blob/master/load_im_url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
start=time.time()
link = "/content/images_tags_and_labels.xlsx"
df = pd.read_excel(link)
stop= time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3694 sec

# %%
df.head(5).T

# %%
url = df1.URL[0]

# %%
df1 = df.iloc[:,[2,6,7]]
df1.head(2)

# %%
import urllib.request
start=time.time()
a=urllib.request.urlretrieve(url, 'image.jpg')
stop=time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3373 sec

# %%
import IPython
from IPython.display import Image, display
start=time.time()


a = IPython.display.Image(url)

stop=time.time()

print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
#display(a)
# Out:
# durée: 0.0 min 0.3381 sec

# %%
import shutil
import requests
from PIL import Image
start=time.time()
response = requests.get(url, stream=True)
with open('my_image.png', 'wb') as file:
    shutil.copyfileobj(response.raw, file)
del response
img = Image.open('my_image.png')
stop=time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))

img.show()
# Out:
# durée: 0.0 min 0.3393 sec

# %%
from PIL import Image
import requests
import urllib
start=time.time()
im = Image.open(urllib.request.urlopen(url))
stop=time.time()
print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3407 sec

# %%
import requests
from PIL import Image
import io
import cv2
start=time.time()
response = requests.get(url,stream=True).content

im = Image.open(io.BytesIO(response))
stop=time.time()

print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))
# Out:
# durée: 0.0 min 0.3424 sec

# %%
from skimage import io
import matplotlib.pyplot as plt
start=time.time()
image = io.imread(url)
stop=time.time()

print("durée: {:.2} min {:.4} sec".format((stop - start) // 60,(stop - start) % 60))

plt.imshow(image)
plt.show()
# Out:
# durée: 0.0 min 0.5115 sec
